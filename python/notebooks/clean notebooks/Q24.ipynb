# %%
# create new folder
# import os
# import sys
# os.chdir(sys.path[3])
# q_research= 'Q24'
# fol_to_q_research = r'python/notebooks/output/{}'.format(q_research)
# os.mkdir(fol_to_q_research )
# os.mkdir(r'{}/{}'.format(fol_to_q_research,'figs'))
# os.mkdir(r'{}/{}'.format(fol_to_q_research,'csv'))

# %%
import sys
import os

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (25, 20),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %%
import pandas as pd
from pandas import DataFrame

import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
os.chdir(sys.path[3])
data_general = pd.read_csv(r'data/process/new_data.csv', skiprows=[1, 2]).reset_index()
data_general= data_general[data_general['Q18']=='Yes (including if damaged) ']

# %%
data_general
# Out:
#       index        StartDate          EndDate      Status       IPAddress  \
# 4         4   4/22/2022 9:08   4/22/2022 9:24  IP Address     24.52.45.71
# 12       12  4/22/2022 11:59  4/22/2022 12:06  IP Address   172.58.46.144
# 15       15  4/22/2022 15:46  4/22/2022 15:54  IP Address   172.58.24.250
# 18       18  4/22/2022 18:11  4/22/2022 18:17  IP Address    23.17.63.224
# 20       20  4/23/2022 18:00  4/23/2022 18:14  IP Address   72.198.57.234
# ...     ...              ...              ...         ...             ...
# 1976   1976    6/1/2022 9:10   6/1/2022 10:44  IP Address   98.171.142.89
# 1986   1986   6/1/2022 21:01   6/1/2022 21:08  IP Address  174.194.202.64
# 1988   1988    6/2/2022 6:04    6/2/2022 6:09  IP Address  104.62.161.218
# 2011   2011   6/4/2022 12:30   6/5/2022 14:34  IP Address    98.60.66.166
# 2017   2017    6/6/2022 9:41    6/6/2022 9:48  IP Address    98.173.167.2
#
#       Progress  Duration (in seconds)  Finished     RecordedDate  \
# 4          100                    968      True   4/22/2022 9:24
# 12         100                    447      True  4/22/2022 12:06
# 15         100                    431      True  4/22/2022 15:54
# 18         100                    365      True  4/22/2022 18:17
# 20         100                    834      True  4/23/2022 18:14
# ...        ...                    ...       ...              ...
# 1976       100                   5626      True   6/1/2022 10:44
# 1986       100                    378      True   6/1/2022 21:08
# 1988       100                    328      True    6/2/2022 6:09
# 2011       100                  93867      True   6/5/2022 14:34
# 2017       100                    458      True    6/6/2022 9:48
#
#              ResponseId  ...  Q33_9_TEXT     Q34    Q35  \
# 4     R_3F2LBFhUg7Q8AbI  ...         NaN  1959.0    Man
# 12    R_dhfK2aYioBlxNBv  ...         NaN  1950.0    Man
# 15    R_2aa7pZekXZm89pb  ...         NaN  1966.0    Man
# 18    R_1hLTjwnbRFOjKOD  ...         NaN  1966.0  Woman
# 20    R_AI2OiSntoyzHkNX  ...         NaN  1948.0    Man
# ...                 ...  ...         ...     ...    ...
# 1976  R_YSIuSlYqzqWbv57  ...         NaN  1971.0    Man
# 1986  R_2DSndRdlUwJM5Fr  ...         NaN  1977.0  Woman
# 1988  R_DeZUrzWw0Cq2Zbj  ...         NaN  1970.0    Man
# 2011  R_25GzXFZytf3CUK5  ...         NaN  1992.0    Man
# 2017  R_2Wu6y2nEalVFrQI  ...         NaN  1955.0    Man
#
#                                          Q36            Q37  \
# 4     Between $100,000 and $149,999 per year         Three
# 12                    Under $20,000 per year           One
# 15                    Under $20,000 per year           Two
# 18                 $200,000 or more per year  Five or more
# 20    Between $150,000 and $199,999 per year         Three
# ...                                      ...            ...
# 1976    Between $50,000 and $74,999 per year  Five or more
# 1986  Between $100,000 and $149,999 per year         Four
# 1988    Between $75,000 and $99,999 per year  Five or more
# 2011  Between $100,000 and $149,999 per year         Four
# 2017    Between $75,000 and $99,999 per year         Three
#
#                                                     Q38  \
# 4     Associate’s/vocational/technical degree (2- or...
# 12                         Some university (no degree)
# 15    Associate’s/vocational/technical degree (2- or...
# 18    Bachelor’s degree (university 4-year degree)  ...
# 20    Bachelor’s degree (university 4-year degree)  ...
# ...                                                 ...
# 1976  Associate’s/vocational/technical degree (2- or...
# 1986  Graduate degree (e.g., Master’s, Professional ...
# 1988  Bachelor’s degree (university 4-year degree)  ...
# 2011  Graduate degree (e.g., Master’s, Professional ...
# 2017  Bachelor’s degree (university 4-year degree)  ...
#
#                                                     Q39 Q39_10_TEXT  \
# 4                       Multi-ethnic (2+ ethnic groups)         NaN
# 12    European (e.g., British Isles, German, French,...         NaN
# 15                      Multi-ethnic (2+ ethnic groups)         NaN
# 18    European (e.g., British Isles, German, French,...         NaN
# 20    European (e.g., British Isles, German, French,...         NaN
# ...                                                 ...         ...
# 1976                             I prefer to not answer         NaN
# 1986  European (e.g., British Isles, German, French,...         NaN
# 1988  European (e.g., British Isles, German, French,...         NaN
# 2011  European (e.g., British Isles, German, French,...         NaN
# 2017  European (e.g., British Isles, German, French,...         NaN
#
#                                                     Q40             Q40_3_TEXT
# 4                                                 Email                    NaN
# 12                              Other (please specify):                Online
# 15                                                Email                    NaN
# 18                                                Email                    NaN
# 20                                                Email                    NaN
# ...                                                 ...                    ...
# 1976                            Other (please specify):  Random face book link
# 1986                            Other (please specify):               Facebook
# 1988  A bicycle registry/recovery system (e.g., Bike...                    NaN
# 2011                                              Email                    NaN
# 2017                                              Email                    NaN
#
# [281 rows x 75 columns]

# %% [markdown]
# ## Questions analysis based on recovery and non-recovery:

# %%
q_research= 'Q24'
cols = list(data_general[data_general[q_research].notnull()][q_research].unique())
colors =['green','orange']
abbr = {'Q2':'part','Q4':'year','Q5':'month','Q6':'day_time','Q7':'is_locked','Q8':'locked_type','Q9':'theft_location','Q10':'is_regi','Q11':'report_loc','Q12':'is_insured','Q13':'estimate_val','Q14':'is_electric','Q15':'bike_type','Q17':'is_university','Q19':'is_online','Q21':'is_police_assist','Q23':'recovery_loc','Q24':'con_recovery','Q34': 'birth', 'Q35': 'gender', 'Q36': 'income', 'Q38': 'education', 'Q39': 'ethnic_origin'}
cols
# Out:
# ['Rideable– bicycle was safe to operate and immediately usable',
#  'Repairable– bicycle was damaged and repairs were required before being rideable',
#  'Salvage/junk– bicycle was not rideable or repairable',
#  'Don’t know/not sure']

# %% [markdown]
# ## All the demographic parameters

# %%
data_store= []
# The code run over each tuple
for pair in {'Q8':'locked_type', 'Q13':'estimate_val', 'Q15':'bike_type',}.items():
    print(pair)
    # Get the question number and its new name
    question_number = pair[0]
    per_name = pair[1]
    # count stat per non/recovery and question_number
    sumy = DataFrame(index=list(data_general[data_general[question_number].notnull()][question_number].unique()))
    for i,name in enumerate(cols):
        rel_demographic = DataFrame(data_general[data_general[q_research] == name][question_number])

        # Rearrange data
        rel_demographic = rel_demographic.rename(columns={question_number: per_name})
        rel_demographic = rel_demographic[rel_demographic[per_name].notna()].reset_index()

        # calculate absolute and relative count for each veritable
        sumy[[name]] = rel_demographic.groupby(by=[per_name]).count().rename(columns={'index': name})
        sumy.index.name = per_name
    # add the new data to datastore which will present latter
    data_store.append(sumy.fillna(0).astype('int32'))
# Out:
# ('Q8', 'locked_type')
# ('Q13', 'estimate_val')
# ('Q15', 'bike_type')

# %%
data_store
# Out:
# [                      The police found it and returned it to me​  \
#  estimate_val
#  $2000-3999                                                    30
#  $1000-$1999                                                   19
#  $500-$999                                                     21
#  $4000-6999                                                     9
#  $7000 or more                                                  3
#  $250-$499                                                     12
#  Less than $250                                                 2
#  Don’t know/not sure                                            0
#
#                        I recovered it with online support (e.g., Bike Index, Facebook recovery groups)  \
#  estimate_val
#  $2000-3999                                                           10
#  $1000-$1999                                                          15
#  $500-$999                                                             9
#  $4000-6999                                                            6
#  $7000 or more                                                         4
#  $250-$499                                                             9
#  Less than $250                                                        4
#  Don’t know/not sure                                                   0
#
#                        ​I found and recovered it myself   \
#  estimate_val
#  $2000-3999                                            8
#  $1000-$1999                                          17
#  $500-$999                                            14
#  $4000-6999                                            3
#  $7000 or more                                         1
#  $250-$499                                             9
#  Less than $250                                        1
#  Don’t know/not sure                                   1
#
#                        A member of the public/friend/family member found it and returned it to me  \
#  estimate_val
#  $2000-3999                                                            8
#  $1000-$1999                                                           5
#  $500-$999                                                             5
#  $4000-6999                                                            3
#  $7000 or more                                                         5
#  $250-$499                                                             1
#  Less than $250                                                        1
#  Don’t know/not sure                                                   0
#
#                        Other (please specify):
#  estimate_val
#  $2000-3999                                 12
#  $1000-$1999                                10
#  $500-$999                                   8
#  $4000-6999                                  6
#  $7000 or more                               2
#  $250-$499                                   6
#  Less than $250                              0
#  Don’t know/not sure                         0  ,
#                             The police found it and returned it to me​  \
#  gender
#  Man                                                                59
#  Woman                                                              33
#  Non-binary / third gender                                           0
#  Prefer not to say                                                   0
#
#                             I recovered it with online support (e.g., Bike Index, Facebook recovery groups)  \
#  gender
#  Man                                                                       28
#  Woman                                                                     23
#  Non-binary / third gender                                                  0
#  Prefer not to say                                                          2
#
#                             ​I found and recovered it myself   \
#  gender
#  Man                                                       33
#  Woman                                                     17
#  Non-binary / third gender                                  2
#  Prefer not to say                                          0
#
#                             A member of the public/friend/family member found it and returned it to me  \
#  gender
#  Man                                                                       18
#  Woman                                                                     10
#  Non-binary / third gender                                                  0
#  Prefer not to say                                                          0
#
#                             Other (please specify):
#  gender
#  Man                                             27
#  Woman                                           16
#  Non-binary / third gender                        0
#  Prefer not to say                                1  ,
#                                          The police found it and returned it to me​  \
#  income
#  Between $100,000 and $149,999 per year                                          14
#  Under $20,000 per year                                                           0
#  $200,000 or more per year                                                       18
#  Between $150,000 and $199,999 per year                                          11
#  Between $50,000 and $74,999 per year                                            12
#  Between $35,000 and $49,999 per year                                             4
#  Between $75,000 and $99,999 per year                                            10
#  I prefer to not answer                                                          14
#  Between $20,000 and $34,999 per year                                             9
#  Don’t know/not sure                                                              0
#
#                                          I recovered it with online support (e.g., Bike Index, Facebook recovery groups)  \
#  income
#  Between $100,000 and $149,999 per year                                                 12
#  Under $20,000 per year                                                                  1
#  $200,000 or more per year                                                               6
#  Between $150,000 and $199,999 per year                                                  5
#  Between $50,000 and $74,999 per year                                                    6
#  Between $35,000 and $49,999 per year                                                    2
#  Between $75,000 and $99,999 per year                                                   12
#  I prefer to not answer                                                                  4
#  Between $20,000 and $34,999 per year                                                    4
#  Don’t know/not sure                                                                     0
#
#                                          ​I found and recovered it myself   \
#  income
#  Between $100,000 and $149,999 per year                                  7
#  Under $20,000 per year                                                  6
#  $200,000 or more per year                                              10
#  Between $150,000 and $199,999 per year                                  1
#  Between $50,000 and $74,999 per year                                    9
#  Between $35,000 and $49,999 per year                                    3
#  Between $75,000 and $99,999 per year                                    8
#  I prefer to not answer                                                  3
#  Between $20,000 and $34,999 per year                                    3
#  Don’t know/not sure                                                     2
#
#                                          A member of the public/friend/family member found it and returned it to me  \
#  income
#  Between $100,000 and $149,999 per year                                                  5
#  Under $20,000 per year                                                                  1
#  $200,000 or more per year                                                               5
#  Between $150,000 and $199,999 per year                                                  6
#  Between $50,000 and $74,999 per year                                                    5
#  Between $35,000 and $49,999 per year                                                    2
#  Between $75,000 and $99,999 per year                                                    2
#  I prefer to not answer                                                                  1
#  Between $20,000 and $34,999 per year                                                    0
#  Don’t know/not sure                                                                     1
#
#                                          Other (please specify):
#  income
#  Between $100,000 and $149,999 per year                        6
#  Under $20,000 per year                                        3
#  $200,000 or more per year                                    12
#  Between $150,000 and $199,999 per year                        7
#  Between $50,000 and $74,999 per year                          6
#  Between $35,000 and $49,999 per year                          1
#  Between $75,000 and $99,999 per year                          5
#  I prefer to not answer                                        3
#  Between $20,000 and $34,999 per year                          1
#  Don’t know/not sure                                           0  ,
#                                                      The police found it and returned it to me​  \
#  education
#  Associate’s/vocational/technical degree (2- or ...                                          13
#  Some university (no degree)                                                                  7
#  Bachelor’s degree (university 4-year degree)   ...                                          38
#  Graduate degree (e.g., Master’s, Professional d...                                          29
#  Some high school or less                      \t                                             0
#  Graduated high school (i.e., High school diplom...                                           3
#  I prefer to not answer                                                                       1
#
#                                                      I recovered it with online support (e.g., Bike Index, Facebook recovery groups)  \
#  education
#  Associate’s/vocational/technical degree (2- or ...                                                  1
#  Some university (no degree)                                                                         4
#  Bachelor’s degree (university 4-year degree)   ...                                                 25
#  Graduate degree (e.g., Master’s, Professional d...                                                 20
#  Some high school or less                      \t                                                    0
#  Graduated high school (i.e., High school diplom...                                                  0
#  I prefer to not answer                                                                              3
#
#                                                      ​I found and recovered it myself   \
#  education
#  Associate’s/vocational/technical degree (2- or ...                                  1
#  Some university (no degree)                                                         9
#  Bachelor’s degree (university 4-year degree)   ...                                 23
#  Graduate degree (e.g., Master’s, Professional d...                                 16
#  Some high school or less                      \t                                    1
#  Graduated high school (i.e., High school diplom...                                  2
#  I prefer to not answer                                                              0
#
#                                                      A member of the public/friend/family member found it and returned it to me  \
#  education
#  Associate’s/vocational/technical degree (2- or ...                                                  2
#  Some university (no degree)                                                                         2
#  Bachelor’s degree (university 4-year degree)   ...                                                 10
#  Graduate degree (e.g., Master’s, Professional d...                                                 12
#  Some high school or less                      \t                                                    1
#  Graduated high school (i.e., High school diplom...                                                  1
#  I prefer to not answer                                                                              0
#
#                                                      Other (please specify):
#  education
#  Associate’s/vocational/technical degree (2- or ...                        2
#  Some university (no degree)                                               5
#  Bachelor’s degree (university 4-year degree)   ...                        9
#  Graduate degree (e.g., Master’s, Professional d...                       27
#  Some high school or less                      \t                          0
#  Graduated high school (i.e., High school diplom...                        1
#  I prefer to not answer                                                    0  ]

# %%
per_cols_by_ans = ['per_'+ col for col in cols]
## It combines two real and percentage values into one column
def prep_for_export(test):
    real = test[cols].apply(lambda x: str(int(x))).reset_index(drop=True)
    per = test[per_cols_by_ans].apply(lambda x: ' ('  + str(int(round(x,0))) + '%' + ')').reset_index(drop=True)
    return real + per

# %%
for dft in data_store:
    df= dft.copy()
    q_name = df.index.name
    print(q_name)
    # Calculate recovery-based distributions for the possible answers to a given question

    sum_per_answer = df.sum(axis=1)
    df[per_cols_by_ans] = df.div(sum_per_answer, axis=0)*100

    # Less popular answers  should be removed, which is relative to the number of possible answers
    temp_sum = df[cols].sum().sum()
    tolerance = temp_sum/(len(df)*2)
    rem_df = df[sum_per_answer<tolerance]
    print('those are not include in the results presentation since less than {} tolerance  {}'.format(tolerance,rem_df))
    new_df = df[sum_per_answer>tolerance]
    # Make a table to export with the real and relative (%) values on the same column
    df_table= DataFrame(columns=cols)
    df_table[df_table.columns] = new_df.apply(lambda x: prep_for_export(x),axis=1)
    df_table.to_csv('python/notebooks/output/{}/csv/'.format(q_research)+ q_name +'.csv')
    df_table

    # Plot the results and save them on the disk
    df_show= DataFrame(columns=cols)
    df_show[cols] = new_df[per_cols_by_ans]
    df_show.plot.bar(stacked=True)
    plt.savefig('python/notebooks/output/{}/figs/'.format(q_research)+q_name+'.png')

    # Indicate when there is interesting results
    find_max= df_show.copy()
    # res save the index of the one with max absolute distance from the average
    res= (abs(find_max.mean() - find_max).idxmax())
    def is_intersting_def(temp_col):
        df_filter = temp_col.reset_index() # Move the question to a column
        outlier_place = df_filter.columns[-1]  # The state to examine
        outlier_att = res[outlier_place] # A possible outlier answer

        # The value for  the possible outlier answer
        is_intersting = df_filter[df_filter[q_name]==outlier_att]
        val_outlier = is_intersting[outlier_place]
        val_outlier
        # Determine the mean and standard deviation without taking into account suspicious outlier
        not_outlier = df_filter[df_filter[q_name]!=outlier_att][outlier_place]
        new_mean = not_outlier.mean()
        new_std = not_outlier.std()
        # Test to determine if it is an outlier and to find out if the results are interesting
        if (abs(val_outlier - new_mean) - new_std> 0).any():
            print ('for {} ({}) : {} is outlier (new_mean:{}, new_std:{})'.format(outlier_place,round(val_outlier.values[0],2),outlier_att,round(new_mean,2),round(new_std,2)))
    res =find_max.apply(is_intersting_def)
# Out:
# locked_type
# those are not include in the results presentation since less than 2.8095238095238093 tolerance                                                      Rideable– bicycle was safe to operate and immediately usable  \
# locked_type
# Folding lock                                                                                        1
# ​U-lock      ,Locking skewers                                                                       1
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                                                  1
# Cable lock ,Other (please specify):                                                                 1
# Two U-Locks                                                                                         1
# Chain-lock combination (chain with mini u-lock ...                                                  0
# ​U-lock      ,Chain-lock combination (chain wit...                                                  1
# Chain-lock with padlock ,Cable lock ,Other (ple...                                                  1
# Chain-lock with padlock ,Frame lock (aka wheel ...                                                  0
# Chain-lock combination (chain with mini u-lock ...                                                  0
# ​U-lock      ,Chain-lock with padlock ,Cable lock                                                   0
# Frame lock (aka wheel lock/O-lock/ring lock)                                                        0
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                                                  1
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                                                  1
# Cable lock ,Don’t know/not sure                                                                     0
#
#                                                     Repairable– bicycle was damaged and repairs were required before being rideable  \
# locked_type
# Folding lock                                                                                        0
# ​U-lock      ,Locking skewers                                                                       1
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                                                  0
# Cable lock ,Other (please specify):                                                                 1
# Two U-Locks                                                                                         1
# Chain-lock combination (chain with mini u-lock ...                                                  1
# ​U-lock      ,Chain-lock combination (chain wit...                                                  0
# Chain-lock with padlock ,Cable lock ,Other (ple...                                                  0
# Chain-lock with padlock ,Frame lock (aka wheel ...                                                  1
# Chain-lock combination (chain with mini u-lock ...                                                  1
# ​U-lock      ,Chain-lock with padlock ,Cable lock                                                   1
# Frame lock (aka wheel lock/O-lock/ring lock)                                                        0
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                                                  0
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                                                  0
# Cable lock ,Don’t know/not sure                                                                     1
#
#                                                     Salvage/junk– bicycle was not rideable or repairable  \
# locked_type
# Folding lock                                                                                        0
# ​U-lock      ,Locking skewers                                                                       0
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                                                  0
# Cable lock ,Other (please specify):                                                                 0
# Two U-Locks                                                                                         0
# Chain-lock combination (chain with mini u-lock ...                                                  0
# ​U-lock      ,Chain-lock combination (chain wit...                                                  0
# Chain-lock with padlock ,Cable lock ,Other (ple...                                                  0
# Chain-lock with padlock ,Frame lock (aka wheel ...                                                  0
# Chain-lock combination (chain with mini u-lock ...                                                  0
# ​U-lock      ,Chain-lock with padlock ,Cable lock                                                   0
# Frame lock (aka wheel lock/O-lock/ring lock)                                                        0
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                                                  0
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                                                  0
# Cable lock ,Don’t know/not sure                                                                     0
#
#                                                     Don’t know/not sure  \
# locked_type
# Folding lock                                                          0
# ​U-lock      ,Locking skewers                                         0
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                    0
# Cable lock ,Other (please specify):                                   0
# Two U-Locks                                                           0
# Chain-lock combination (chain with mini u-lock ...                    0
# ​U-lock      ,Chain-lock combination (chain wit...                    0
# Chain-lock with padlock ,Cable lock ,Other (ple...                    0
# Chain-lock with padlock ,Frame lock (aka wheel ...                    0
# Chain-lock combination (chain with mini u-lock ...                    0
# ​U-lock      ,Chain-lock with padlock ,Cable lock                     0
# Frame lock (aka wheel lock/O-lock/ring lock)                          0
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                    0
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                    0
# Cable lock ,Don’t know/not sure                                       0
#
#                                                     per_Rideable– bicycle was safe to operate and immediately usable  \
# locked_type
# Folding lock                                                                                    100.0
# ​U-lock      ,Locking skewers                                                                    50.0
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                                              100.0
# Cable lock ,Other (please specify):                                                              50.0
# Two U-Locks                                                                                      50.0
# Chain-lock combination (chain with mini u-lock ...                                                0.0
# ​U-lock      ,Chain-lock combination (chain wit...                                              100.0
# Chain-lock with padlock ,Cable lock ,Other (ple...                                              100.0
# Chain-lock with padlock ,Frame lock (aka wheel ...                                                0.0
# Chain-lock combination (chain with mini u-lock ...                                                0.0
# ​U-lock      ,Chain-lock with padlock ,Cable lock                                                 0.0
# Frame lock (aka wheel lock/O-lock/ring lock)                                                      NaN
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                                              100.0
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                                              100.0
# Cable lock ,Don’t know/not sure                                                                   0.0
#
#                                                     per_Repairable– bicycle was damaged and repairs were required before being rideable  \
# locked_type
# Folding lock                                                                                      0.0
# ​U-lock      ,Locking skewers                                                                    50.0
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                                                0.0
# Cable lock ,Other (please specify):                                                              50.0
# Two U-Locks                                                                                      50.0
# Chain-lock combination (chain with mini u-lock ...                                              100.0
# ​U-lock      ,Chain-lock combination (chain wit...                                                0.0
# Chain-lock with padlock ,Cable lock ,Other (ple...                                                0.0
# Chain-lock with padlock ,Frame lock (aka wheel ...                                              100.0
# Chain-lock combination (chain with mini u-lock ...                                              100.0
# ​U-lock      ,Chain-lock with padlock ,Cable lock                                               100.0
# Frame lock (aka wheel lock/O-lock/ring lock)                                                      NaN
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                                                0.0
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                                                0.0
# Cable lock ,Don’t know/not sure                                                                 100.0
#
#                                                     per_Salvage/junk– bicycle was not rideable or repairable  \
# locked_type
# Folding lock                                                                                      0.0
# ​U-lock      ,Locking skewers                                                                     0.0
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                                                0.0
# Cable lock ,Other (please specify):                                                               0.0
# Two U-Locks                                                                                       0.0
# Chain-lock combination (chain with mini u-lock ...                                                0.0
# ​U-lock      ,Chain-lock combination (chain wit...                                                0.0
# Chain-lock with padlock ,Cable lock ,Other (ple...                                                0.0
# Chain-lock with padlock ,Frame lock (aka wheel ...                                                0.0
# Chain-lock combination (chain with mini u-lock ...                                                0.0
# ​U-lock      ,Chain-lock with padlock ,Cable lock                                                 0.0
# Frame lock (aka wheel lock/O-lock/ring lock)                                                      NaN
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                                                0.0
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                                                0.0
# Cable lock ,Don’t know/not sure                                                                   0.0
#
#                                                     per_Don’t know/not sure
# locked_type
# Folding lock                                                            0.0
# ​U-lock      ,Locking skewers                                           0.0
# ​U-lock      ,Cable lock ,Frame lock (aka wheel...                      0.0
# Cable lock ,Other (please specify):                                     0.0
# Two U-Locks                                                             0.0
# Chain-lock combination (chain with mini u-lock ...                      0.0
# ​U-lock      ,Chain-lock combination (chain wit...                      0.0
# Chain-lock with padlock ,Cable lock ,Other (ple...                      0.0
# Chain-lock with padlock ,Frame lock (aka wheel ...                      0.0
# Chain-lock combination (chain with mini u-lock ...                      0.0
# ​U-lock      ,Chain-lock with padlock ,Cable lock                       0.0
# Frame lock (aka wheel lock/O-lock/ring lock)                            NaN
# ​U-lock      ,Two U-Locks ,Chain-lock combinati...                      0.0
# Cable lock ,Frame lock (aka wheel lock/O-lock/r...                      0.0
# Cable lock ,Don’t know/not sure                                         0.0
#                                                    Rideable– bicycle was safe to operate and immediately usable  \
# locked_type
# ​U-lock                                                                                      13 (46%)
# Cable lock                                                                                   20 (51%)
# Chain-lock with padlock                                                                       6 (75%)
# Chain-lock combination (chain with mini u-lock ...                                            4 (44%)
# Other (please specify):                                                                       9 (64%)
# ​U-lock      ,Cable lock                                                                      2 (67%)
#
#                                                    Repairable– bicycle was damaged and repairs were required before being rideable  \
# locked_type
# ​U-lock                                                                                      11 (39%)
# Cable lock                                                                                   15 (38%)
# Chain-lock with padlock                                                                       1 (12%)
# Chain-lock combination (chain with mini u-lock ...                                            4 (44%)
# Other (please specify):                                                                       5 (36%)
# ​U-lock      ,Cable lock                                                                      1 (33%)
#
#                                                    Salvage/junk– bicycle was not rideable or repairable  \
# locked_type
# ​U-lock                                                                                       3 (11%)
# Cable lock                                                                                     3 (8%)
# Chain-lock with padlock                                                                       1 (12%)
# Chain-lock combination (chain with mini u-lock ...                                            1 (11%)
# Other (please specify):                                                                        0 (0%)
# ​U-lock      ,Cable lock                                                                       0 (0%)
#
#                                                    Don’t know/not sure
# locked_type
# ​U-lock                                                         1 (4%)
# Cable lock                                                      1 (3%)
# Chain-lock with padlock                                         0 (0%)
# Chain-lock combination (chain with mini u-lock ...              0 (0%)
# Other (please specify):                                         0 (0%)
# ​U-lock      ,Cable lock                                        0 (0%)
# <AxesSubplot:xlabel='locked_type'>
# for Rideable– bicycle was safe to operate and immediately usable (75.0) : Chain-lock with padlock  is outlier (new_mean:54.62, new_std:10.25)
# for Repairable– bicycle was damaged and repairs were required before being rideable (12.5) : Chain-lock with padlock  is outlier (new_mean:38.25, new_std:4.19)
# for Salvage/junk– bicycle was not rideable or repairable (0.0) : Other (please specify): is outlier (new_mean:8.4, new_std:5.01)
# for Don’t know/not sure (3.57) : ​U-lock       is outlier (new_mean:0.51, new_std:1.15)
# estimate_val
# those are not include in the results presentation since less than 7.375 tolerance                        Rideable– bicycle was safe to operate and immediately usable  \
# estimate_val
# $7000 or more                                                         3
# Less than $250                                                        2
# Don’t know/not sure                                                   1
#
#                       Repairable– bicycle was damaged and repairs were required before being rideable  \
# estimate_val
# $7000 or more                                                         2
# Less than $250                                                        1
# Don’t know/not sure                                                   0
#
#                       Salvage/junk– bicycle was not rideable or repairable  \
# estimate_val
# $7000 or more                                                         0
# Less than $250                                                        0
# Don’t know/not sure                                                   0
#
#                       Don’t know/not sure  \
# estimate_val
# $7000 or more                           0
# Less than $250                          0
# Don’t know/not sure                     0
#
#                       per_Rideable– bicycle was safe to operate and immediately usable  \
# estimate_val
# $7000 or more                                                 60.000000
# Less than $250                                                66.666667
# Don’t know/not sure                                          100.000000
#
#                       per_Repairable– bicycle was damaged and repairs were required before being rideable  \
# estimate_val
# $7000 or more                                                 40.000000
# Less than $250                                                33.333333
# Don’t know/not sure                                            0.000000
#
#                       per_Salvage/junk– bicycle was not rideable or repairable  \
# estimate_val
# $7000 or more                                                       0.0
# Less than $250                                                      0.0
# Don’t know/not sure                                                 0.0
#
#                       per_Don’t know/not sure
# estimate_val
# $7000 or more                             0.0
# Less than $250                            0.0
# Don’t know/not sure                       0.0
#                   Rideable– bicycle was safe to operate and immediately usable  \
# estimate_val
# $2000-3999                                                  11 (38%)
# $1000-$1999                                                 17 (59%)
# $500-$999                                                   14 (58%)
# $4000-6999                                                   6 (55%)
# $250-$499                                                    9 (56%)
#
#                   Repairable– bicycle was damaged and repairs were required before being rideable  \
# estimate_val
# $2000-3999                                                  14 (48%)
# $1000-$1999                                                 12 (41%)
# $500-$999                                                    5 (21%)
# $4000-6999                                                   5 (45%)
# $250-$499                                                    6 (38%)
#
#                   Salvage/junk– bicycle was not rideable or repairable  \
# estimate_val
# $2000-3999                                                   3 (10%)
# $1000-$1999                                                   0 (0%)
# $500-$999                                                    4 (17%)
# $4000-6999                                                    0 (0%)
# $250-$499                                                     1 (6%)
#
#                   Don’t know/not sure
# estimate_val
# $2000-3999                     1 (3%)
# $1000-$1999                    0 (0%)
# $500-$999                      1 (4%)
# $4000-6999                     0 (0%)
# $250-$499                      0 (0%)
# <AxesSubplot:xlabel='estimate_val'>
# for Rideable– bicycle was safe to operate and immediately usable (37.93) : $2000-3999       is outlier (new_mean:56.94, new_std:1.91)
# for Repairable– bicycle was damaged and repairs were required before being rideable (20.83) : $500-$999  is outlier (new_mean:43.15, new_std:4.71)
# for Salvage/junk– bicycle was not rideable or repairable (16.67) : $500-$999  is outlier (new_mean:4.15, new_std:5.07)
# for Don’t know/not sure (4.17) : $500-$999  is outlier (new_mean:0.86, new_std:1.72)
# bike_type
# those are not include in the results presentation since less than 4.538461538461538 tolerance                           Rideable– bicycle was safe to operate and immediately usable  \
# bike_type
# Folding                                                                  1
# BMX                                                                      1
# Tandem                                                                   0
# Cruiser                                                                  1
# Tricycle or quadricycle                                                  1
# Don’t know/not sure                                                      0
# Fixed gear                                                               0
# Recumbent                                                                1
#
#                          Repairable– bicycle was damaged and repairs were required before being rideable  \
# bike_type
# Folding                                                                  1
# BMX                                                                      0
# Tandem                                                                   0
# Cruiser                                                                  3
# Tricycle or quadricycle                                                  0
# Don’t know/not sure                                                      0
# Fixed gear                                                               1
# Recumbent                                                                0
#
#                          Salvage/junk– bicycle was not rideable or repairable  \
# bike_type
# Folding                                                                  0
# BMX                                                                      0
# Tandem                                                                   0
# Cruiser                                                                  0
# Tricycle or quadricycle                                                  0
# Don’t know/not sure                                                      0
# Fixed gear                                                               0
# Recumbent                                                                0
#
#                          Don’t know/not sure  \
# bike_type
# Folding                                    0
# BMX                                        0
# Tandem                                     0
# Cruiser                                    0
# Tricycle or quadricycle                    0
# Don’t know/not sure                        0
# Fixed gear                                 0
# Recumbent                                  0
#
#                          per_Rideable– bicycle was safe to operate and immediately usable  \
# bike_type
# Folding                                                               50.0
# BMX                                                                  100.0
# Tandem                                                                 NaN
# Cruiser                                                               25.0
# Tricycle or quadricycle                                              100.0
# Don’t know/not sure                                                    NaN
# Fixed gear                                                             0.0
# Recumbent                                                            100.0
#
#                          per_Repairable– bicycle was damaged and repairs were required before being rideable  \
# bike_type
# Folding                                                               50.0
# BMX                                                                    0.0
# Tandem                                                                 NaN
# Cruiser                                                               75.0
# Tricycle or quadricycle                                                0.0
# Don’t know/not sure                                                    NaN
# Fixed gear                                                           100.0
# Recumbent                                                              0.0
#
#                          per_Salvage/junk– bicycle was not rideable or repairable  \
# bike_type
# Folding                                                                0.0
# BMX                                                                    0.0
# Tandem                                                                 NaN
# Cruiser                                                                0.0
# Tricycle or quadricycle                                                0.0
# Don’t know/not sure                                                    NaN
# Fixed gear                                                             0.0
# Recumbent                                                              0.0
#
#                          per_Don’t know/not sure
# bike_type
# Folding                                      0.0
# BMX                                          0.0
# Tandem                                       NaN
# Cruiser                                      0.0
# Tricycle or quadricycle                      0.0
# Don’t know/not sure                          NaN
# Fixed gear                                   0.0
# Recumbent                                    0.0
#                    Rideable– bicycle was safe to operate and immediately usable  \
# bike_type
# Hybrid/City/Dutch                                            16 (53%)
# Mountain                                                     22 (51%)
# Road                                                         14 (67%)
# Gravel/cyclocross                                             3 (43%)
# Delivery/Cargo                                                3 (43%)
#
#                    Repairable– bicycle was damaged and repairs were required before being rideable  \
# bike_type
# Hybrid/City/Dutch                                            10 (33%)
# Mountain                                                     15 (35%)
# Road                                                          7 (33%)
# Gravel/cyclocross                                             4 (57%)
# Delivery/Cargo                                                4 (57%)
#
#                    Salvage/junk– bicycle was not rideable or repairable  \
# bike_type
# Hybrid/City/Dutch                                             3 (10%)
# Mountain                                                      5 (12%)
# Road                                                           0 (0%)
# Gravel/cyclocross                                              0 (0%)
# Delivery/Cargo                                                 0 (0%)
#
#                    Don’t know/not sure
# bike_type
# Hybrid/City/Dutch               1 (3%)
# Mountain                        1 (2%)
# Road                            0 (0%)
# Gravel/cyclocross               0 (0%)
# Delivery/Cargo                  0 (0%)
# <AxesSubplot:xlabel='bike_type'>
# for Rideable– bicycle was safe to operate and immediately usable (66.67) : Road is outlier (new_mean:47.55, new_std:5.49)
# for Repairable– bicycle was damaged and repairs were required before being rideable (57.14) : Gravel/cyclocross is outlier (new_mean:39.67, new_std:11.67)
# for Salvage/junk– bicycle was not rideable or repairable (11.63) : Mountain   is outlier (new_mean:2.5, new_std:5.0)
# for Don’t know/not sure (3.33) : Hybrid/City/Dutch  is outlier (new_mean:0.58, new_std:1.16)
